# %%
import h5py
import pandas as pd

# %%
cwes = set(open('datasets/combined-cwes.txt', 'r').read().strip().split('\n'))

# %%
cwes

# %%
vdisc_train_file = h5py.File('datasets/vdisc_train.hdf5')
vdisc_test_file = h5py.File('datasets/vdisc_test.hdf5')
vdisc_validate_file = h5py.File('datasets/vdisc_validate.hdf5')

# %%
def load_vdisc_to_pandas(vdisc_h45py):
    
    # Manually construct the data frame as a dict with key=<column name> and value=<list of
    # values for that column>.

    length = vdisc_h45py['functionSource'].size

    raw_dataframe = {
        'testcase_ID': ["vdisc_testcase_{}".format(index) for index in range(length)],
        'flaw_loc': [None]*length,
        'filename': [None]*length,
        'code': vdisc_h45py['functionSource'],
        'CWE-119': vdisc_h45py['CWE-119'],
        'CWE-120': vdisc_h45py['CWE-120'],
        'CWE-469': vdisc_h45py['CWE-469'],
        'CWE-476': vdisc_h45py['CWE-476'],
        'CWE-OTHERS': vdisc_h45py['CWE-other'],
    }

    empty_cwes = [
        cwe for cwe in cwes if cwe not in {
            'CWE-119',
            'CWE-120',
            'CWE-469',
            'CWE-476',
            'CWE-OTHERS',
        }
    ]

    for cwe in empty_cwes:
        raw_dataframe[cwe] = [False]*length


    return pd.DataFrame(data=raw_dataframe)

vdisc_train = load_vdisc_to_pandas(vdisc_train_file)
vdisc_test = load_vdisc_to_pandas(vdisc_test_file)
vdisc_validate = load_vdisc_to_pandas(vdisc_validate_file)

# %%
vdisc_train
# Out:
#                     testcase_ID flaw_loc filename  \
# 0              vdisc_testcase_0     None     None
# 1              vdisc_testcase_1     None     None
# 2              vdisc_testcase_2     None     None
# 3              vdisc_testcase_3     None     None
# 4              vdisc_testcase_4     None     None
# ...                         ...      ...      ...
# 1019466  vdisc_testcase_1019466     None     None
# 1019467  vdisc_testcase_1019467     None     None
# 1019468  vdisc_testcase_1019468     None     None
# 1019469  vdisc_testcase_1019469     None     None
# 1019470  vdisc_testcase_1019470     None     None
#
#                                                       code  CWE-119  CWE-120  \
# 0        b'clear_area(int startx, int starty, int xsize...    False    False
# 1        b'ReconstructDuList(Statement* head)\n{\n    S...    False    False
# 2        b'free_speaker(void)\n{\n   if(Lengths)\n     ...    False    False
# 3        b'mlx4_register_device(struct mlx4_dev *dev)\n...    False    False
# 4        b'Parse_Env_Var(void)\n{\n  char *p = getenv("...     True     True
# ...                                                    ...      ...      ...
# 1019466  b'visitICmpInst(ICmpInst &I) {\n  // We must c...    False    False
# 1019467  b'path_node_delete_chain(path_node * head)\n{\...    False    False
# 1019468  b'addrconf6_start (NMDevice *self)\n{\n\tNMDev...    False    False
# 1019469  b'Next(const SQObjectPtr &refpos, SQObjectPtr ...    False    False
# 1019470  b'EffectHealMaxHealth(SpellEffectIndex /*eff_i...    False    False
#
#          CWE-469  CWE-476  CWE-OTHERS  CWE-259  ...  CWE-843  CWE-534  \
# 0          False    False       False    False  ...    False    False
# 1          False    False       False    False  ...    False    False
# 2          False    False       False    False  ...    False    False
# 3          False    False       False    False  ...    False    False
# 4          False    False        True    False  ...    False    False
# ...          ...      ...         ...      ...  ...      ...      ...
# 1019466    False    False       False    False  ...    False    False
# 1019467    False    False       False    False  ...    False    False
# 1019468    False    False       False    False  ...    False    False
# 1019469    False    False       False    False  ...    False    False
# 1019470    False    False       False    False  ...    False    False
#
#          CWE-114  CWE-535  CWE-226  CWE-247  CWE-366  CWE-482  CWE-832  \
# 0          False    False    False    False    False    False    False
# 1          False    False    False    False    False    False    False
# 2          False    False    False    False    False    False    False
# 3          False    False    False    False    False    False    False
# 4          False    False    False    False    False    False    False
# ...          ...      ...      ...      ...      ...      ...      ...
# 1019466    False    False    False    False    False    False    False
# 1019467    False    False    False    False    False    False    False
# 1019468    False    False    False    False    False    False    False
# 1019469    False    False    False    False    False    False    False
# 1019470    False    False    False    False    False    False    False
#
#          CWE-675
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
# ...          ...
# 1019466    False
# 1019467    False
# 1019468    False
# 1019469    False
# 1019470    False
#
# [1019471 rows x 126 columns]

# %%
vdisc_train["CWE-119"].unique()
# Out:
# array([False,  True])

# %%
vdisc_train.to_csv('datasets/vdisc_train.csv')
vdisc_test.to_csv('datasets/vdisc_test.csv')
vdisc_validate.to_csv('datasets/vdisc_validate.csv')

# %%
df=pd.read_csv('datasets/vdisc_train.csv')
df
# Out:
#          Unnamed: 0             testcase_ID  flaw_loc  filename  \
# 0                 0        vdisc_testcase_0       NaN       NaN
# 1                 1        vdisc_testcase_1       NaN       NaN
# 2                 2        vdisc_testcase_2       NaN       NaN
# 3                 3        vdisc_testcase_3       NaN       NaN
# 4                 4        vdisc_testcase_4       NaN       NaN
# ...             ...                     ...       ...       ...
# 1019466     1019466  vdisc_testcase_1019466       NaN       NaN
# 1019467     1019467  vdisc_testcase_1019467       NaN       NaN
# 1019468     1019468  vdisc_testcase_1019468       NaN       NaN
# 1019469     1019469  vdisc_testcase_1019469       NaN       NaN
# 1019470     1019470  vdisc_testcase_1019470       NaN       NaN
#
#                                                       code  CWE-119  CWE-120  \
# 0        b'clear_area(int startx, int starty, int xsize...    False    False
# 1        b'ReconstructDuList(Statement* head)\n{\n    S...    False    False
# 2        b'free_speaker(void)\n{\n   if(Lengths)\n     ...    False    False
# 3        b'mlx4_register_device(struct mlx4_dev *dev)\n...    False    False
# 4        b'Parse_Env_Var(void)\n{\n  char *p = getenv("...     True     True
# ...                                                    ...      ...      ...
# 1019466  b'visitICmpInst(ICmpInst &I) {\n  // We must c...    False    False
# 1019467  b'path_node_delete_chain(path_node * head)\n{\...    False    False
# 1019468  b'addrconf6_start (NMDevice *self)\n{\n\tNMDev...    False    False
# 1019469  b'Next(const SQObjectPtr &refpos, SQObjectPtr ...    False    False
# 1019470  b'EffectHealMaxHealth(SpellEffectIndex /*eff_i...    False    False
#
#          CWE-469  CWE-476  CWE-OTHERS  ...  CWE-843  CWE-534  CWE-114  \
# 0          False    False       False  ...    False    False    False
# 1          False    False       False  ...    False    False    False
# 2          False    False       False  ...    False    False    False
# 3          False    False       False  ...    False    False    False
# 4          False    False        True  ...    False    False    False
# ...          ...      ...         ...  ...      ...      ...      ...
# 1019466    False    False       False  ...    False    False    False
# 1019467    False    False       False  ...    False    False    False
# 1019468    False    False       False  ...    False    False    False
# 1019469    False    False       False  ...    False    False    False
# 1019470    False    False       False  ...    False    False    False
#
#          CWE-535  CWE-226  CWE-247  CWE-366  CWE-482  CWE-832  CWE-675
# 0          False    False    False    False    False    False    False
# 1          False    False    False    False    False    False    False
# 2          False    False    False    False    False    False    False
# 3          False    False    False    False    False    False    False
# 4          False    False    False    False    False    False    False
# ...          ...      ...      ...      ...      ...      ...      ...
# 1019466    False    False    False    False    False    False    False
# 1019467    False    False    False    False    False    False    False
# 1019468    False    False    False    False    False    False    False
# 1019469    False    False    False    False    False    False    False
# 1019470    False    False    False    False    False    False    False
#
# [1019471 rows x 127 columns]

# %%
df["flaw_loc"].unique()
# Out:
# array([nan])
